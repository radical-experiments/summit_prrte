# %%
# %matplotlib inline
# %run 'bin/notebook_utils.py'
# %run 'bin/plot_utilization.py'
import matplotlib.ticker as mticker
# Out:
# <style>.container { width:100% !important; }</style>

# %%
! radical-stack
# Out:
#   python               : 3.7.7
#   pythonpath           :
#   virtualenv           : /Users/mturilli/.virtualenvs/analytics-devel
#
#   radical.analytics    : 0.90.7-v0.72.0-49-gdf96ecd@feature-wrangler
#   radical.pilot        : 1.4.0-v1.4.0-48-gafbdfc311@devel
#   radical.saga         : 1.4.0
#   radical.utils        : 1.4.0

# %%
suds = [
        'rp.session.login3.mturilli1.018442.0011',
        'rp.session.login3.mturilli1.018442.0012'
       ] 
sdir = '../data/raw/'
sids = [sdir+s for s in suds]

# %%
ss = {}
for sid in suds:
    sp = sdir+sid
    ss[sid] = {'s': ra.Session(sp, 'radical.pilot')}
    ss[sid].update({'p': ss[sid]['s'].filter(etype='pilot'   , inplace=False),
                    'u': ss[sid]['s'].filter(etype='unit'    , inplace=False),
                    't': ss[sid]['s'].filter(etype='task'    , inplace=False),
                    'w': ss[sid]['s'].filter(etype='pipeline', inplace=False)})
# Out:
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/cmgr.0002.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_scheduling_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_unschedule_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_output_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_scheduling_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/log_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/cmgr.0001.hb.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_output_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/control_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.prof" not correctly closed.
# session loaded
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/cmgr.0002.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_scheduling_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_unschedule_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_output_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_scheduling_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/log_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/cmgr.0001.hb.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_output_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/control_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.prof" not correctly closed.
# session loaded
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/cmgr.0002.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_scheduling_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_unschedule_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_output_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_scheduling_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/log_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/cmgr.0001.hb.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_output_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/control_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.prof" not correctly closed.
# session loaded
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/cmgr.0002.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_scheduling_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_unschedule_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_output_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_scheduling_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/log_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/cmgr.0001.hb.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_output_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/control_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.prof" not correctly closed.
# session loaded
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/cmgr.0002.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_scheduling_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_unschedule_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_output_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_scheduling_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/heartbeat.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/state_pubsub.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_input_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/log_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/cmgr.0001.hb.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/umgr_staging_output_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/control_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0011/pmgr_launching_queue.prof" not correctly closed.
# session loaded
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/cmgr.0002.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_scheduling_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/heartbeat.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/heartbeat.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/pmgr_launching_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_input_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_unschedule_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_input_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_output_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.sub.0000.prof" not correctly closed.
# session loaded
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/cmgr.0002.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_scheduling_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/heartbeat.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/heartbeat.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/pmgr_launching_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_input_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_unschedule_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_input_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_output_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.sub.0000.prof" not correctly closed.
# session loaded
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/cmgr.0002.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_scheduling_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/heartbeat.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/heartbeat.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/pmgr_launching_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_input_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_unschedule_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_input_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_output_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.sub.0000.prof" not correctly closed.
# session loaded
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/cmgr.0002.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_scheduling_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/heartbeat.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/heartbeat.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/pmgr_launching_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_input_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_unschedule_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_input_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_output_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.sub.0000.prof" not correctly closed.
# session loaded
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.pub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/cmgr.0002.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_scheduling_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/heartbeat.sub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/heartbeat.sub.0001.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/pmgr_launching_queue.get.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_input_queue.put.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_unschedule_pubsub.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.pub.0000.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_input_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/umgr_staging_output_queue.prof" not correctly closed.
# WARNING: profile "../data/raw/rp.session.login3.mturilli1.018442.0012/state_pubsub.sub.0000.prof" not correctly closed.
# session loaded

# %%
for sid in suds:
    ss[sid].update({'sid'   : ss[sid]['s'].uid,
                    'pid'   : ss[sid]['p'].list('uid'),
                    'npilot': len(ss[sid]['p'].get()),
                    'lm'    : ss[sid]['s'].get(etype='pilot')[0].cfg['agent_launch_method'],
                    'npact' : len(ss[sid]['p'].timestamps(state='PMGR_ACTIVE')),
                    'nunit' : len(ss[sid]['u'].get()),
                    'nudone': len(ss[sid]['u'].timestamps(state='DONE')),
                    'nufail': len(ss[sid]['u'].timestamps(state='FAILED'))})
    ss[sid].update({'pres'  : ss[sid]['p'].get(uid=ss[sid]['pid'])[0].description['resource'],
                    'ncores': ss[sid]['p'].get(uid=ss[sid]['pid'])[0].description['cores'],
                    'ngpus' : ss[sid]['p'].get(uid=ss[sid]['pid'])[0].description['gpus']})                  
    ss[sid].update({'nnodes': ss[sid]['ngpus']/6})

# %%
for sid in suds:
    print("""
# %s:
\tName of the HPC platform: %s
\tPilot launch method: %s
\tNumber of pilots requested: %i
\tNumber of pilots active: %i
\tNumber of requested cores: %i
\tNumber of requested GPUs: %s
\tNumber of requested nodes: %s
\tNumber of nodes asked by ENTK: %i
\tNumber of tasks executed by EnTK: %i
\tNumber of tasks successfully executed by EnTK: %i
\tNumber of failed tasks: %i
""" % (sid              , ss[sid]['pres']  , ss[sid]['lm'], 
       ss[sid]['npilot'], ss[sid]['npact'] , ss[sid]['ncores']/4, 
       ss[sid]['ngpus'] , ss[sid]['nnodes'], ss[sid]['ncores']/168, 
       ss[sid]['nunit'] , ss[sid]['nudone'], ss[sid]['nufail']))
# Out:
# rp.session.login3.mturilli1.018442.0011:
# 	Name of the HPC platform: ornl.summit
# 	Pilot launch method: JSRUN
# 	Number of pilots requested: 1
# 	Number of pilots active: 1
# 	Number of requested cores: 42
# 	Number of requested GPUs: 6
# 	Number of requested nodes: 1.0
# 	Number of nodes asked by ENTK: 1
# 	Number of tasks executed by EnTK: 11
# 	Number of tasks successfully executed by EnTK: 11
# 	Number of failed tasks: 0
#
#
# rp.session.login3.mturilli1.018442.0012:
# 	Name of the HPC platform: ornl.summit_prte
# 	Pilot launch method: SSH
# 	Number of pilots requested: 1
# 	Number of pilots active: 1
# 	Number of requested cores: 42
# 	Number of requested GPUs: 6
# 	Number of requested nodes: 1.0
# 	Number of nodes asked by ENTK: 1
# 	Number of tasks executed by EnTK: 11
# 	Number of tasks successfully executed by EnTK: 11
# 	Number of failed tasks: 0

# %%
UNIT_DURATIONS_DEBUG = {
    'consume' : {
        'u_umngr_create'               : [ {ru.EVENT: 'state'           , ru.STATE: rp.NEW                         },      
                                           {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_SCHEDULING_PENDING     }  ],
        'u_umngr_schedule_queue'       : [ {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_SCHEDULING_PENDING     }, 
                                           {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_SCHEDULING             }  ],
        'u_umngr_schedule'             : [ {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_SCHEDULING             },               
                                           {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_STAGING_INPUT_PENDING  }  ],
        'u_umngr_stage_in_queue'       : [ {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_STAGING_INPUT_PENDING  }, 
                                           {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_STAGING_INPUT          }  ], # push to mongodb
        'u_umngr_stage_in'             : [ {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_STAGING_INPUT          }, 
                                           {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_STAGING_INPUT_PENDING }  ], # wait in mongodb
        'u_agent_stage_in_queue'       : [ {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_STAGING_INPUT_PENDING },  
                                           {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_STAGING_INPUT         }  ], # pull from mongodb 
        'u_agent_stage_in'             : [ {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_STAGING_INPUT         },  
                                           {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_SCHEDULING_PENDING    }  ], 
        'u_agent_schedule_queue'       : [ {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_SCHEDULING_PENDING    },  
                                           {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_SCHEDULING            }  ],
        'u_agent_schedule'             : [ {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_SCHEDULING            },  
                                           {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_EXECUTING_PENDING     }  ], 
        'u_agent_execute_queue'        : [ {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_EXECUTING_PENDING     },  
                                           {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_EXECUTING             }  ], 
        'u_agent_execute_mkdir_start'  : [ {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_EXECUTING             },  
                                           {ru.EVENT: 'exec_mkdir'      , ru.STATE: None                           }  ], 
        'u_agent_execute_mkdir'        : [ {ru.EVENT: 'exec_mkdir'      , ru.STATE: None                           },
                                           {ru.EVENT: 'exec_mkdir_done' , ru.STATE: None                           }  ],
        'u_agent_execute_layer_start'  : [ {ru.EVENT: 'exec_mkdir_done' , ru.STATE: None                           },
                                           {ru.EVENT: 'exec_start'      , ru.STATE: None                           }  ],
        'u_agent_execute_layer'        : [ {ru.EVENT: 'exec_start'      , ru.STATE: None                           },
                                          [{ru.EVENT: 'exec_ok'         , ru.STATE: None                           },
                                           {ru.EVENT: 'exec_fail'       , ru.STATE: None                           } ]], # orte, ssh, mpi, ... 

        'u_agent_cu_start'             : [ {ru.EVENT: 'cu_start'        , ru.STATE: None                           },
                                           {ru.EVENT: 'cu_cd_done'      , ru.STATE: None                           }  ], # PROBLEM: discontinuity
        'u_agent_cu_pre_execute_start' : [ {ru.EVENT: 'cu_cd_done'      , ru.STATE: None                           },
                                           {ru.EVENT: 'cu_pre_start'    , ru.STATE: None                           }  ],
        'u_agent_cu_pre_execute'       : [ {ru.EVENT: 'cu_pre_start'    , ru.STATE: None                           },
                                           {ru.EVENT: 'cu_pre_stop'     , ru.STATE: None                           }  ],
        'u_agent_cu_execute_start'     : [ {ru.EVENT: 'cu_pre_stop'     , ru.STATE: None                           },
                                           {ru.EVENT: 'cu_exec_start'   , ru.STATE: None                           }  ],
        'u_agent_cu_execute'           : [ {ru.EVENT: 'cu_exec_start'   , ru.STATE: None                           },
                                           {ru.EVENT: 'cu_exec_stop'    , ru.STATE: None                           }  ],
        'u_agent_cu_stop'              : [ {ru.EVENT: 'cu_exec_stop'    , ru.STATE: None                           },
                                           {ru.EVENT: 'cu_stop'         , ru.STATE: None                           }  ],

        'u_agent_cu_unschedule_start'  : [ {ru.EVENT: 'exec_stop'       , ru.STATE: None                           },
                                           {ru.EVENT: 'unschedule_start', ru.STATE: None                           }  ], # PROBLEM: discontinuity
        'u_agent_cu_stage_out_start'   : [ {ru.EVENT: 'unschedule_start', ru.STATE: None                           },
                                           {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_STAGING_OUTPUT_PENDING}  ],
        'u_agent_cu_stage_out_queue'   : [ {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_STAGING_OUTPUT_PENDING},
                                           {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_STAGING_OUTPUT        }  ],
        'u_agent_cu_stage_out'         : [ {ru.EVENT: 'state'           , ru.STATE: rp.AGENT_STAGING_OUTPUT        },
                                           {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_STAGING_OUTPUT_PENDING }  ],
        'u_agent_cu_unschedule_stop'   : [ {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_STAGING_OUTPUT_PENDING },
                                         {ru.EVENT: 'unschedule_stop' , ru.STATE: None                           }  ],
        'u_agent_cu_push_to_umngr'     : [ {ru.EVENT: 'unschedule_stop' , ru.STATE: None                           },
                                           {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_STAGING_OUTPUT         }  ], # push/pull mongodb
        'u_umngr_cu_destroy'           : [ {ru.EVENT: 'state'           , ru.STATE: rp.UMGR_STAGING_OUTPUT         },
                                          [{ru.EVENT: 'state'           , ru.STATE: rp.DONE                        },
                                           {ru.EVENT: 'state'           , ru.STATE: rp.CANCELED                    },
                                           {ru.EVENT: 'state'           , ru.STATE: rp.FAILED                      } ]]
    }
}

# %%
u_durations = {}

for sid in suds:
    u_durations[sid] = {}

for sid in suds:
    for uid in ss[sid]['u'].list('uid'):
        unit = ss[sid]['u'].get(etype='unit', uid=uid)[0]
        durations = {}
        for k,v in UNIT_DURATIONS_DEBUG['consume'].items():
            try:
                durations[k] = unit.duration(event=v)
            except:
                pass
        u_durations[sid].update({uid: durations})

# %%
u_durations_df = {}
for sid,durations in u_durations.items():
    u_durations_df[sid] = pd.DataFrame.from_dict(durations, orient='index')

# %%
fwidth = 10*2
fhight = 14

fig, axarr = plt.subplots(nrows=1, ncols=2, figsize=(fwidth, fhight), sharey=True)

i = 0
j = 'a'
for sid in suds:

    if len(suds) > 1:
        ax = axarr[i]
    else:
        ax = axarr

    labels = []
    muted = [] # 'u_agent_schedule', 'u_agent_cu_execute'

    if set(muted).issubset(u_durations_df[sid].columns):
        durations = u_durations_df[sid].drop(muted, axis=1)
    else:
        durations = u_durations_df[sid]

    for label in durations.columns:
        labels.append(label.replace("_", " ").title().replace("U ", "").replace("Cu", "CU"))
    labels = list(reversed(labels))

    boxes = []
    for duration in list(reversed(durations.columns)):
        boxes.append(durations[duration].values)
        
    ax.title.set_text('%s/%s Tasks/Nodes' % (ss[sid]['nunit'], int(ss[sid]['nnodes'])))

    ax.boxplot(boxes, patch_artist=True, labels=labels, vert=False),

    ax.xaxis.grid(True, linestyle='-', which='major', color='lightgrey', alpha=0.5)
    ax.set_axisbelow(True)
    
    i = i+1
    j = chr(ord(j) + 1)

fig.text( 0.5 , 0.05, 'Time (s)', ha='center', fontsize=24)

plt.savefig('figures/baseline_json_prrte.pdf', dpi=300, bbox_inches='tight')
plt.savefig('figures/baseline_json_prrte.png', dpi=300, bbox_inches='tight')
# Out:
# /Users/mturilli/.virtualenvs/analytics-devel/lib/python3.7/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
metrics_default = [

        # pilot overheads (global)
        ['Pilot Startup',     ['boot', 'setup_1']],
        ['Pilot Termination', ['term' ]],

        # derived pilot durations
        ['Agent Nodes',       ['agent']],
        ['Warmup',            ['warm' ]],
        ['Draining',          ['drain']],
        ['Idle',              ['idle' ]],

        # unit durations (PRTE)
        ['Prepare Exec',      ['exec_queue', 'exec_prep']],
        ['Exec RP',           ['exec_rp', 'exec_sh', 'term_sh', 'term_rp']],
        ['Exec Cmd',          ['exec_cmd']],
        ['Unschedule',        ['unschedule']],
]

# %%
sobjs = ra.Experiment(sids, stype='radical.pilot')
provided, consumed, stats_abs, stats_rel, info = sobjs.utilization(metrics=metrics_default)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-afa3a0dc86a2> in <module>
#       1 sobjs = ra.Experiment(sids, stype='radical.pilot')
# ----> 2 provided, consumed, stats_abs, stats_rel, info = sobjs.utilization(metrics=metrics_default)
#
# ~/.virtualenvs/analytics-devel/lib/python3.7/site-packages/radical/analytics/experiment.py in utilization(self, metrics)
#     114
#     115             sid = session.uid
# --> 116             p, c, sa, sr, i = session.utilization(metrics)
#     117
#     118             provided [sid] = p
#
# ~/.virtualenvs/analytics-devel/lib/python3.7/site-packages/radical/analytics/session.py in utilization(self, metrics)
#     976
#     977         provided  = rp.utils.get_provided_resources(self)
# --> 978         consumed  = rp.utils.get_consumed_resources(self)
#     979         stats_abs = {'total':   0.0}
#     980         stats_rel = {'total': 100.0}
#
# ~/.virtualenvs/analytics-devel/lib/python3.7/site-packages/radical/pilot/utils/prof_utils.py in get_consumed_resources(session)
#     629
#     630         p_min = pt(event=PILOT_DURATIONS['consume']['ignore'][0]) [0]
# --> 631         p_max = pt(event=PILOT_DURATIONS['consume']['ignore'][1])[-1]
#     632       # p_max = pilot.events[-1][ru.TIME]
#     633         log.debug('pmin, pmax: %10.2f / %10.2f', p_min, p_max)
#
# IndexError: list index out of range
